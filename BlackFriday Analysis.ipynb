# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df1=pd.read_csv("BlackFriday.csv")
del df1["Product_Category_2"]
del df1["Product_Category_3"]
df1.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df1.shape
# Out:
# (537577, 10)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Purchase                    537577 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 41.0+ MB

# %%
df1.isna().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %%
 166986/537577*100
# Out:
# 31.06271287648095

# %%
 373299/537577*100
# Out:
# 69.44102891306734

# %%
df1.describe()
# Out:
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  5.375770e+05  537577.00000   537577.000000       537577.000000
# mean   1.002992e+06       8.08271        0.408797            5.295546
# std    1.714393e+03       6.52412        0.491612            3.750701
# min    1.000001e+06       0.00000        0.000000            1.000000
# 25%    1.001495e+06       2.00000        0.000000            1.000000
# 50%    1.003031e+06       7.00000        0.000000            5.000000
# 75%    1.004417e+06      14.00000        1.000000            8.000000
# max    1.006040e+06      20.00000        1.000000           18.000000
#
#             Purchase
# count  537577.000000
# mean     9333.859853
# std      4981.022133
# min       185.000000
# 25%      5866.000000
# 50%      8062.000000
# 75%     12073.000000
# max     23961.000000

# %%
df=df1.copy()

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Purchase'],
#       dtype='object')

# %%
df["User_ID"].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
df["User_ID"].nunique()
# Out:
# 5891

# %%
df["Product_ID"].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00038842',
#        'P00295642', 'P00091742'], dtype=object)

# %%
df["Product_ID"].nunique()
# Out:
# 3623

# %%
df["Gender"].nunique()
# Out:
# 2

# %%
df["Gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df["Age"].nunique()
# Out:
# 7

# %%
df["Age"].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df["Occupation"].nunique()
# Out:
# 21

# %%
df["Occupation"].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
df["City_Category"].nunique()
# Out:
# 3

# %%
df["City_Category"].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df["Stay_In_Current_City_Years"].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df["Stay_In_Current_City_Years"].nunique()
# Out:
# 5

# %%
df["Marital_Status"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df["Marital_Status"].nunique()
# Out:
# 2

# %%
df["Product_Category_1"].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
df["Product_Category_1"].nunique()
# Out:
# 18

# %%
df["Purchase"].unique()
# Out:
# array([ 8370, 15200,  1422, ..., 14539, 11120, 18426], dtype=int64)

# %%
df["Purchase"].nunique()
# Out:
# 17959

# %% [markdown]
# # Analysis

# %%
df["Gender"].value_counts().plot(kind="pie",autopct="%.2f",figsize = (6,6))
# Out:
# <Axes: ylabel='count'>

# %%
df["Gender"].value_counts()
# Out:
# Gender
# M    405380
# F    132197
# Name: count, dtype: int64

# %%
df["Gender"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Gender'>

# %%
len(df["User_ID"].value_counts())
# Out:
# 5891

# %%
df["Age"].value_counts()
# Out:
# Age
# 26-35    214690
# 36-45    107499
# 18-25     97634
# 46-50     44526
# 51-55     37618
# 55+       20903
# 0-17      14707
# Name: count, dtype: int64

# %%
df["Age"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Age'>

# %%
df["Age"].value_counts().plot(kind="pie",autopct="%.2f",figsize = (6,6))
# Out:
# <Axes: ylabel='count'>

# %%
df["Occupation"].value_counts()
# Out:
# Occupation
# 4     70862
# 0     68120
# 7     57806
# 1     45971
# 17    39090
# 20    32910
# 12    30423
# 14    26712
# 2     25845
# 16    24790
# 6     19822
# 3     17366
# 10    12623
# 5     11985
# 15    11812
# 11    11338
# 19     8352
# 13     7548
# 18     6525
# 9      6153
# 8      1524
# Name: count, dtype: int64

# %%
df["Occupation"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df["City_Category"].value_counts()
# Out:
# City_Category
# B    226493
# C    166446
# A    144638
# Name: count, dtype: int64

# %%
df["City_Category"].value_counts().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df["City_Category"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='City_Category'>

# %%
df["Stay_In_Current_City_Years"].value_counts()
# Out:
# Stay_In_Current_City_Years
# 1     189192
# 2      99459
# 3      93312
# 4+     82889
# 0      72725
# Name: count, dtype: int64

# %%
df["Stay_In_Current_City_Years"].value_counts().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df["Stay_In_Current_City_Years"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
df["Marital_Status"].value_counts()
# Out:
# Marital_Status
# 0    317817
# 1    219760
# Name: count, dtype: int64

# %%
df["Marital_Status"].value_counts().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df["Marital_Status"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Marital_Status'>

# %%
df["Product_Category_1"].value_counts()
# Out:
# Product_Category_1
# 5     148592
# 1     138353
# 8     112132
# 11     23960
# 2      23499
# 6      20164
# 3      19849
# 4      11567
# 16      9697
# 15      6203
# 13      5440
# 10      5032
# 12      3875
# 7       3668
# 18      3075
# 14      1500
# 17       567
# 9        404
# Name: count, dtype: int64

# %%
df["Product_Category_1"].value_counts().plot(kind= "bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df["Purchase"].value_counts()
# Out:
# Purchase
# 6855     186
# 7011     185
# 6891     182
# 7193     182
# 6879     181
#         ...
# 7292       1
# 9309       1
# 23128      1
# 21408      1
# 18426      1
# Name: count, Length: 17959, dtype: int64

# %% [markdown]
# #  Dealing with  multiple columns

# %%
df.groupby(by="Gender").size().plot(kind="bar")
# Out:
# <Axes: xlabel='Gender'>

# %%
 sns.countplot(data=df,x="Gender",hue="Age")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
 sns.countplot(data=df,x="Age",hue="Gender")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(data=df,x="Occupation",hue="Gender")
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(data=df,x="Occupation",hue="Gender")
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(data=df,x="City_Category",hue="Gender")
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(data=df,x="Gender",hue="City_Category")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=df,x="Gender",hue="Stay_In_Current_City_Years")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=df,x="Stay_In_Current_City_Years",hue="Gender")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(data=df,x="Marital_Status",hue="Gender")
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
 sns.countplot(data=df,x="Product_Category_1",hue="Gender")
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
 sns.countplot(data=df,x="City_Category",hue="Gender")
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(data=df,x="Age",hue="City_Category")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
df.groupby('Age').size().plot(kind = 'bar', title = 'Purchase Distribution by Age')
# Out:
# <Axes: title={'center': 'Purchase Distribution by Age'}, xlabel='Age'>

# %%
df.groupby("Gender").size().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: >

# %%
df.groupby("Product_Category_1",sort=True).size().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby(["Marital_Status","Gender" ],sort=True).size().plot(kind="bar")
# Out:
# <Axes: xlabel='Marital_Status,Gender'>

# %%
df.groupby(["Age","Gender" ],sort=True).sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Age,Gender'>

# %%
df.groupby(["Age","Gender","Marital_Status" ],sort=True).size().plot(kind="bar")
# Out:
# <Axes: xlabel='Age,Gender,Marital_Status'>

# %%
df.groupby(["Gender","Marital_Status","Stay_In_Current_City_Years"],sort=True).size().plot(kind="bar")
# Out:
# <Axes: xlabel='Gender,Marital_Status,Stay_In_Current_City_Years'>

# %%
df.groupby(["Gender","Stay_In_Current_City_Years"],sort=True).size().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: >

# %%
df.groupby(["Occupation","Gender"]).size().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation,Gender'>

# %%
df.groupby(["City_Category","Age"]).size().plot(kind="bar")
# Out:
# <Axes: xlabel='City_Category,Age'>

# %%
df.groupby(["Stay_In_Current_City_Years","Age"]).size().plot(kind="bar")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years,Age'>

# %%
df.groupby(["Stay_In_Current_City_Years","Marital_Status"]).size().plot(kind="bar")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years,Marital_Status'>

# %%
df.groupby(["Stay_In_Current_City_Years","Marital_Status"]).size().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: >

# %%
df.groupby(["Stay_In_Current_City_Years","Gender"]).size().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: >
